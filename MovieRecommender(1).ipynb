# %%
import pandas as pd
import numpy as np
import os

# %%
movies=pd.read_csv('tmdb_5000_movies.csv')
credits=pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.merge(credits,on='title')
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies=movies.merge(credits, on='title')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
movies=movies[['genres', 'id', 'keywords', 'title', 'overview', 'cast', 'crew']]

# %%
movies.dropna(inplace=True)

# %%
movies=movies.drop_duplicates()

# %%
import ast

def convert(obj):
    # Check if obj is already a list
    if isinstance(obj, list):
        return obj  # Return as-is if it's already a list
    try:
        # Safely evaluate the string into a Python object
        parsed = ast.literal_eval(obj)
        return [i['name'] for i in parsed]
    except (ValueError, SyntaxError, TypeError):
        # Handle any malformed or unexpected data gracefully
        return []  # Return an empty li

# %%
movies['genres']=movies['genres'].apply(convert)

# %%
movies['keywords']=movies['keywords'].apply(convert)

# %%
def convert3(obj):
    counter=0
    L=[]
    for i in ast.literal_eval(obj):
        if counter!=3:
            L.append(i['name'])
            counter+=1
        else:
            break
    return L

# %%
movies['cast']=movies['cast'].apply(convert3)

# %%
def convert4(obj):
    L=[]
    for i in ast.literal_eval(obj):
        if i['job']=='Director':
            L.append(i['name'])
            break
    return L

# %%
movies['crew']=movies['crew'].apply(convert4)

# %%
movies['overview']=movies['overview'].apply(lambda x:x.split())

# %%
movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ", "")for i in x])

# %%
movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ", "")for i in x])

# %%
movies['cast']=movies['cast'].apply(lambda x:[i.replace(" ", "")for i in x])

# %%
movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ", "")for i in x])

# %%
movies['tags']=movies['genres']+movies['keywords']+movies['overview']+movies['cast']+movies['crew']

# %%
moviess=movies[['id', 'tags', 'title']]

# %%
moviess['tags']=movies['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\bhoom\AppData\Local\Temp\ipykernel_29228\81866062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moviess['tags']=movies['tags'].apply(lambda x:" ".join(x))

# %%
moviess['tags']=moviess['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\bhoom\AppData\Local\Temp\ipykernel_29228\3392183788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moviess['tags']=moviess['tags'].apply(lambda x:x.lower())

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
moviess['tags']=moviess['tags'].apply(stem)
# Out:
# C:\Users\bhoom\AppData\Local\Temp\ipykernel_29228\2713582543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moviess['tags']=moviess['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000, stop_words='english')

# %%
vectors=cv.fit_transform(moviess['tags']).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vectors)

# %%
def recommend(movie):
    movie_ind=moviess[moviess['title']==movie].index[0]
    distances=similarity[movie_ind]
    movies_list=sorted(list(enumerate(distances)),reverse=True,key=(lambda x:x[1]))[1:6]

    for i in movies_list:
        print(movies.iloc[i[0]].title)

# %%
pip install ipywidgets
# Out:
# ...
#
# ...

# %%
import ipywidgets as widgets
from IPython.display import display

# Ensure you have the movie titles in a list
movie_list = moviess['title'].tolist()  # Replace 'title' with the actual column name in your DataFrame

# Dropdown for selecting a movie
movie_dropdown = widgets.Dropdown(
    options=movie_list,  # List of movie titles
    description='Movie:',
    value=movie_list[0]  # Set the first movie as the default value
)

# Button to trigger recommendation
recommend_button = widgets.Button(description="Recommend")

# Output display
output = widgets.Output()

# Function to handle recommendations
def on_recommend_button_clicked(b):
    with output:
        output.clear_output()
        selected_movie = movie_dropdown.value
        print(f"Recommendations for {selected_movie}:")
        # Replace with your recommend function
        # recommended_movies = recommend(selected_movie)
        # for movie in recommended_movies:
        #     print(movie)

# Link button to function
recommend_button.on_click(on_recommend_button_clicked)

# Display widgets
display(movie_dropdown, recommend_button, output)
